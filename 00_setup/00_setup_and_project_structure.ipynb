# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.11.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

PROJECT_DIR = "/content/drive/MyDrive/MTechIndProj/MoM_Project"

print("Project directory:")
print(PROJECT_DIR)
directories = [
    "00_setup",
    "01_audio_vad",
    "02_asr_diarization",
    "03_dialogue_act",
    "04_mom_generation",
    "05_evidence_retrieval",
    "06_verification",
    "07_dashboard",
    "08_evaluation",

    "data/raw",
    "data/audio",
    "data/vad",
    "data/transcripts",
    "data/dialogue_acts",
    "data/references",

    "models/asr",
    "models/diarization",
    "models/dialogue_act",
    "models/llm",

    "outputs/mom",
    "outputs/evidence",
    "outputs/verified",
    "outputs/pdf",

    "evaluation_results"
]

for directory in directories:
    path = os.path.join(PROJECT_DIR, directory)
    os.makedirs(path, exist_ok=True)

print("All project directories created.")
# Out:
# Project directory:
# /content/drive/MyDrive/MTechIndProj/MoM_Project
# All project directories created.

# %%
for root, dirs, files in os.walk(PROJECT_DIR):
    level = root.replace(PROJECT_DIR, "").count(os.sep)
    indent = "    " * level
    print(f"{indent}{os.path.basename(root)}/")
# Out:
# MoM_Project/
#     00_setup/
#     01_audio_vad/
#     02_asr_diarization/
#     03_dialogue_act/
#     04_mom_generation/
#     05_evidence_retrieval/
#     06_verification/
#     07_dashboard/
#     08_evaluation/
#     data/
#         raw/
#         audio/
#         vad/
#         transcripts/
#         dialogue_acts/
#         references/
#     models/
#         asr/
#         diarization/
#         dialogue_act/
#         llm/
#     outputs/
#         mom/
#         evidence/
#         verified/
#         pdf/
#     evaluation_results/

# %%
# !apt-get update -qq
# !apt-get install -y ffmpeg
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 78 not upgraded.

# %%
# !ffmpeg -version
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
# built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
# libavutil      56. 70.100 / 56. 70.100
# libavcodec     58.134.100 / 58.134.100
# libavformat    58. 76.100 / 58. 76.100
# libavdevice    58. 13.100 / 58. 13.100
# libavfilter     7.110.100 /  7.110.100
# libswscale      5.  9.100 /  5.  9.100
# libswresample   3.  9.100 /  3.  9.100
# libpostproc    55.  9.100 / 55.  9.100

# %%
## Haven't run all the packages yet

# !pip install -q \
    whisperx \
    transformers \
    sentence-transformers \
    faiss-cpu \
    accelerate \
    peft \
    datasets \
    evaluate \
    rouge-score \
    bert-score \
    gradio \
    reportlab \
    pandas \
    numpy \
    scikit-learn

# %%
import pandas as pd
import numpy as np
import torch
import transformers
import sentence_transformers
import faiss
import gradio

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Transformers:", transformers.__version__)
print("Sentence Transformers:", sentence_transformers.__version__)
print("FAISS:", faiss.__version__)
print("Gradio:", gradio.__version__)
print("Torch:", torch.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1608/3914776169.py in <cell line: 0>()
#       3 import torch
#       4 import transformers
# ----> 5 import sentence_transformers
#       6 import faiss
#       7 import gradio
#
# /usr/local/lib/python3.13/dist-packages/sentence_transformers/__init__.py in <module>
#       8 import warnings
#       9
# ---> 10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#
# /usr/local/lib/python3.13/dist-packages/sentence_transformers/backend/__init__.py in <module>
#       3 from .load import load_onnx_model, load_openvino_model
#       4 from .optimize import export_optimized_onnx_model
# ----> 5 from .quantize import export_dynamic_quantized_onnx_model, export_static_quantized_openvino_model
#       6 from .utils import _save_pretrained_wrapper, backend_should_export, backend_warn_to_save, save_or_push_to_hub_model
#       7
#
# /usr/local/lib/python3.13/dist-packages/sentence_transformers/backend/quantize.py in <module>
#       5
#       6 from sentence_transformers.backend.utils import save_or_push_to_hub_model
# ----> 7 from sentence_transformers.util import disable_datasets_caching, is_datasets_available
#       8
#       9 logger = logging.getLogger(__name__)
#
# /usr/local/lib/python3.13/dist-packages/sentence_transformers/util/__init__.py in <module>
#      24 )
#      25 from .quantization import quantize_embeddings
# ---> 26 from .retrieval import (
#      27     community_detection,
#      28     information_retrieval,
#
# /usr/local/lib/python3.13/dist-packages/sentence_transformers/util/retrieval.py in <module>
#      12 from tqdm.autonotebook import tqdm
#      13
# ---> 14 from .similarity import cos_sim
#      15 from .tensor import normalize_embeddings
#      16
#
# /usr/local/lib/python3.13/dist-packages/sentence_transformers/util/similarity.py in <module>
#       7 import torch
#       8 from numpy import ndarray
# ----> 9 from sklearn.metrics import pairwise_distances
#      10 from torch import Tensor
#      11 from transformers.utils import logging
#
# /usr/local/lib/python3.13/dist-packages/sklearn/__init__.py in <module>
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      75
#
# /usr/local/lib/python3.13/dist-packages/sklearn/base.py in <module>
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/__init__.py in <module>
#      13 from . import _joblib, metadata_routing
#      14 from ._bunch import Bunch
# ---> 15 from ._chunking import gen_batches, gen_even_slices
#      16 from ._estimator_html_repr import estimator_html_repr
#      17
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/_chunking.py in <module>
#       9
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      12
#      13
#
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/_param_validation.py in <module>
#      12
#      13 import numpy as np
# ---> 14 from scipy.sparse import csr_matrix, issparse
#      15
#      16 from .._config import config_context, get_config
#
# /usr/local/lib/python3.13/dist-packages/scipy/sparse/__init__.py in <module>
#     302 import importlib as _importlib
#     303
# --> 304 from ._base import *
#     305 from ._csr import *
#     306 from ._csc import *
#
# /usr/local/lib/python3.13/dist-packages/scipy/sparse/_base.py in <module>
#       6 import operator
#       7
# ----> 8 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       9                        get_sum_dtype, isdense, isscalarlike, _todata,
#      10                        matrix, validateaxis, getdtype, is_pydata_spmatrix)
#
# /usr/local/lib/python3.13/dist-packages/scipy/sparse/_sputils.py in <module>
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      11
#      12
#
# /usr/local/lib/python3.13/dist-packages/scipy/_lib/_util.py in <module>
#      12
#      13 import numpy as np
# ---> 14 from scipy._lib._array_api import (Array, array_namespace, is_lazy_array,
#      15                                    is_numpy, is_marray, xp_result_device,
#      16                                    xp_size, xp_result_type)
#
# /usr/local/lib/python3.13/dist-packages/scipy/_lib/_array_api.py in <module>
#      23
#      24 from scipy._lib import array_api_compat
# ---> 25 from scipy._lib.array_api_compat import (
#      26     is_array_api_obj,
#      27     is_lazy_array,
#
# /usr/local/lib/python3.13/dist-packages/scipy/_lib/array_api_compat/numpy/__init__.py in <module>
#       2 from typing import Final
#       3
# ----> 4 from numpy import *  # noqa: F403  # pyright: ignore[reportWildcardImportFromLibrary]
#       5
#       6 # from numpy import * doesn't overwrite these builtin names
#
# /usr/local/lib/python3.13/dist-packages/numpy/testing/__init__.py in <module>
#       9
#      10 from . import _private, overrides
# ---> 11 from ._private import extbuild
#      12 from ._private.utils import *
#      13 from ._private.utils import _assert_valid_refcount, _gen_alignment_data
#
# /usr/local/lib/python3.13/dist-packages/numpy/testing/_private/extbuild.py in <module>
#      11 import textwrap
#      12
# ---> 13 from .utils import run_subprocess
#      14
#      15 __all__ = ['build_and_import_extension', 'compile_extension_module']
#
# /usr/local/lib/python3.13/dist-packages/numpy/testing/_private/utils.py in <module>
#      92 IS_PYSTON = hasattr(sys, "pyston_version_info")
#      93 HAS_REFCOUNT = getattr(sys, 'getrefcount', None) is not None and not IS_PYSTON
# ---> 94 BLAS_SUPPORTS_FPE = np._core._multiarray_umath._blas_supports_fpe(None)
#      95
#      96 HAS_LAPACK64 = numpy.linalg._umath_linalg._ilp64
#
# AttributeError: module 'numpy._core._multiarray_umath' has no attribute '_blas_supports_fpe'

# %%
import sys
import numpy as np

print("Python:", sys.version)
print("NumPy:", np.__version__)
# Out:
# Python: 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]
# NumPy: 2.1.3

# %%
# !pip install -q --force-reinstall \
    "numpy==1.26.4" \
    "scipy==1.13.1" \
    "scikit-learn==1.5.2"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 82.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 13.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... canceled
# ERROR: Operation cancelled by user

# %% [markdown]
# After everytime we reinstall any library ,we need to restart the runtime ie.,Session restart

# %%
import sys
import numpy as np

print("Python:", sys.version)
print("NumPy:", np.__version__)

try:
    import scipy
    print("SciPy:", scipy.__version__)
except Exception as e:
    print("SciPy ERROR:", repr(e))

try:
    import sklearn
    print("Scikit-learn:", sklearn.__version__)
except Exception as e:
    print("Scikit-learn ERROR:", repr(e))
# Out:
# Python: 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]
# NumPy: 2.5.2
# SciPy: 1.16.3
# Scikit-learn: 1.6.1

# %%
import numpy as np
import numpy.testing

print("NumPy OK:", np.__version__)
# Out:
# NumPy OK: 2.5.2

# %%
import scipy

print("SciPy OK:", scipy.__version__)
# Out:
# SciPy OK: 1.16.3

# %%
import sklearn

print("Scikit-learn OK:", sklearn.__version__)
# Out:
# Scikit-learn OK: 1.6.1

# %%
import sentence_transformers

print("Sentence Transformers OK")
print(sentence_transformers.__version__)
# Out:
# Sentence Transformers OK
# 5.7.0

# %%
import faiss
print("FAISS OK")
print("FAISS version:", faiss.__version__)
# Out:
# FAISS OK
# FAISS version: 1.15.0

# %%
import numpy as np
import faiss

test_vectors = np.random.rand(10, 384).astype("float32")

index = faiss.IndexFlatIP(384)
index.add(test_vectors)

print("FAISS test successful!")
print("Vectors stored:", index.ntotal)
# Out:
# FAISS test successful!
# Vectors stored: 10

# %%
import transformers

print("Transformers OK")
print("Version:", transformers.__version__)
# Out:
# Transformers OK
# Version: 4.57.6

# %%
import gradio

print("Gradio OK")
print("Version:", gradio.__version__)
# Out:
# Gradio OK
# Version: 6.17.3

# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.8.0+cu128
# CUDA available: True
# GPU: Tesla T4
